# %%
import pandas as pd

# %%
# Load the spreadsheet
df = pd.read_excel("Cmeg_bacterial_data.xlsx", sheet_name="Trimmed")
display(df.head(10))
# Out:
#          OTU   Kingdom            Phylum                Class  \
# 0  Otu000581  Bacteria  Bdellovibrionota          Oligoflexia
# 1  Otu001358  Bacteria   Acidobacteriota       Blastocatellia
# 2  Otu003953  Bacteria    Proteobacteria  Alphaproteobacteria
# 3  Otu016921  Bacteria      Bacteroidota          Bacteroidia
# 4  Otu118871  Bacteria  Actinobacteriota      Thermoleophilia
# 5  Otu136851  Bacteria       Chloroflexi         Anaerolineae
# 6  Otu173283  Bacteria   Patescibacteria      Gracilibacteria
# 7  Otu003848  Bacteria    Proteobacteria  Alphaproteobacteria
# 8  Otu000183  Bacteria    Proteobacteria  Alphaproteobacteria
# 9  Otu000257  Bacteria    Proteobacteria  Alphaproteobacteria
#
#                          Order                          Family  \
# 0                    0319-6G20                    0319-6G20_fa
# 1          2023-11-24 00:00:00                        11-24_fa
# 2                  Rhizobiales                Beijerinckiaceae
# ...
